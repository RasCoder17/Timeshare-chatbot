# %%
# !pip install --upgrade langchain openai  -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# ...

# %%
! pipe install cohere tiktoken
# Out:
# /bin/bash: line 1: pipe: command not found

# %%
# !pip installed and sentence_transformers -q
# Out:
# ERROR: unknown command "installed" - maybe you meant "install"

# %%
# !pip install fastapi kaleido uvicorn python-multipart
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 9.4 MB/s eta 0:00:00
# ...

# %%
# %pip install unstructured -q
# %pip install unstructured[local-inference] -q
# %pip install detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.9/457.9 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 41.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 38.6 MB/s eta 0:00:00
# ...

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 31 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.3 [186 kB]
# Fetched 186 kB in 0s (861 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 121671 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.3_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.3) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.3) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# https://python.langchain.com/en/latest/modules/indexes/document_loaders/examples/directory_loader.html

# %%
from langchain.document_loaders import DirectoryLoader

directory ='/content/sample_data/ProblemS'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# 4

# %% [markdown]
# https://python.langchain.com/en/latest/modules/indexes/text_splitters/getting_started.html

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_docs(documents,chunk_size=500,chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 35

# %%
print(docs[8].page_content)
# Out:
# 8. Governing Law and Dispute Resolu9on: This Agreement and any disputes arising hereunder shall be governed by the laws of the jurisdicOon of the selected resort at the Ome of dispute. Any disputes shall ﬁrst seek resoluOon through mediaOon, followed by arbitraOon, if necessary, as detailed in Annexure C.
#
# 9. Signatures: Both parOes hereby agree to the terms and condiOons set forth in this Agreement and aﬃx their signatures as follows:
#
# Resort Owner: ___________________________ Date: _________

# %%
docs
# Out:
# [Document(page_content='TIMESHARE AGREEMENT\n\nThis Timeshare Agreement ("Agreement") is entered into on this [Date], by and between Blue Horizon Ventures LLC, hereinaBer referred to as "Resort Owner," with a principal address at [Resort Owner Address] and [Purchaser\'s Full Name], hereinaBer referred to as "Purchaser," with a principal address at [Purchaser Address].\n\nWhereas, the Resort Owner is the lawful owner of various Omeshare properOes situated at mulOple locaOons as detailed in Annexure A; and', metadata={'source': '/content/sample_data/ProblemS/TIMESHARE_AGREEMENT.pdf'}),
#  Document(page_content='Whereas, the Purchaser desires to acquire a Omeshare interest in one or more of the Resorts subject to the terms and condiOons set forth herein;\n\nNow, Therefore, in consideraOon of the mutual promises and covenants contained herein, the parOes agree as follows:', metadata={'source': '/content/sample_data/ProblemS/TIMESHARE_AGREEMENT.pdf'}),
# ...

# %%
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.7 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=06d4d7c376430d31b6aef3be6839d66d6ad7155b5b7143bcbef6e6a0d7d45a7a
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...

# %%
# import openai
# from langchain.embeddings.openai import OpenAIEmbeddings
# embeddings = OpenAIEmbeddings(model_name="ada")
from langchain.embeddings import SentenceTransformerEmbeddings
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# ), model_name='all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False)

# %%
query_result = embeddings.embed_query("Hello world")
len(query_result)
# Out:
# 384

# %%
query_result
# Out:
# [-0.034477271139621735,
#  0.0310231801122427,
#  0.006734997965395451,
#  0.026108959689736366,
#  -0.03936203569173813,
#  -0.16030244529247284,
#  0.06692398339509964,
#  -0.006441446021199226,
#  -0.0474504791200161,
#  0.014758843928575516,
#  0.07087528705596924,
#  0.055527616292238235,
#  0.01919332519173622,
#  -0.026251347735524178,
#  -0.01010959129780531,
#  -0.026940450072288513,
#  0.02230745181441307,
#  -0.022226683795452118,
#  -0.1496926099061966,
#  -0.01749301515519619,
#  0.007676273118704557,
#  0.0543522834777832,
#  0.0032544205896556377,
#  0.0317259207367897,
#  -0.08462149649858475,
#  -0.029405983164906502,
#  0.051595594733953476,
#  0.04812406376004219,
#  -0.0033148264046758413,
#  -0.058279186487197876,
#  0.04196928068995476,
#  0.02221069484949112,
#  0.128188818693161,
#  -0.02233893796801567,
#  -0.011656254529953003,
#  0.06292837858200073,
#  -0.03287634626030922,
#  -0.09122609347105026,
#  -0.03117532841861248,
#  0.05269954726099968,
# ...

# %%
# !pip install pinecone-client -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 1.6 MB/s eta 0:00:00

# %% [markdown]
# https://python.langchain.com/en/latest/modules/indexes/vectorstores/examples/pinecone.html

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key="8eeccd25-faab-4b54-8553-a17cbe358ece")

index_name = "langchain-chatbot"
index = pc.Index('langchain-chatbot')
if index_name not in pc.list_indexes().names():
  # Do something, such as create the index
  pc.create_index(
    name=index_name,
    dimension=384,
    metric='cosine',
    spec=ServerlessSpec(
      cloud="gcp",
      region="us-central1"
    )
  )

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.00035,
#  'namespaces': {'': {'vector_count': 35}},
#  'total_vector_count': 35}

# %%
import itertools
import random

# Assuming 'index' is already created and initialized

# Assuming 'docs' is a list of split documents
docs = split_docs(documents)

vector_dim = 384

# Example generator that generates many (id, vector) pairs for documents
docs_data_generator = map(lambda i_doc: (f'id-{i_doc[0]}', [random.random() for _ in range(vector_dim)]), enumerate(docs))

def chunks(iterable, batch_size=100):
    """A helper function to break an iterable into chunks of size batch_size."""
    it = iter(iterable)
    chunk = tuple(itertools.islice(it, batch_size))
    while chunk:
        yield chunk
        chunk = tuple(itertools.islice(it, batch_size))

# Upsert data with 100 vectors per upsert request
batch_size = 100
for ids_vectors_chunk,doc in zip(chunks(docs_data_generator, batch_size=batch_size), docs):

    print(ids_vectors_chunk)
    break
    # Assuming 'index' is the Pinecone index created and initialized earlier
    index.delete(vectors=ids_vectors_chunk,metadata=metadata_list)
# Out:
# (('id-0', [0.8145155816700054, 0.2967464521226314, 0.9401241237272729, 0.14131072322885618, 0.8335866329724108, 0.6397296020497946, 0.3302271853155786, 0.15211588385692554, 0.7974954203920611, 0.1899896136508995, 0.10963435716575443, 0.6996753765694411, 0.318090981682729, 0.29514985204509026, 0.45230352641020466, 0.22837681771245422, 0.640899341275439, 0.9120119798132336, 0.3701017908492288, 0.03465584647839959, 0.9328925740029376, 0.856740218212218, 0.3401722544423619, 0.5606139820210735, 0.6897973498009284, 0.07319236688069064, 0.7336228179218508, 0.059561394228521136, 0.18510225090859533, 0.23945567823816793, 0.014944904812378534, 0.5481573724888216, 0.44623919416138547, 0.2853803429598527, 0.7910500588389772, 0.5510296617940181, 0.6748360287876671, 0.04207458493915117, 0.2204294684033007, 0.07652337505840534, 0.006948392693159611, 0.4954246529247597, 0.9305595985597584, 0.7126537274633556, 0.2816807601743656, 0.7397333357210882, 0.13196532621025525, 0.27551449292909613, 0.4624532
# ...

# %%
# lol = doc.Config
print(dir(doc))
# print(doc.class)
# Out:
# ['Config', '__abstractmethods__', '__annotations__', '__class__', '__class_vars__', '__config__', '__custom_root_type__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__exclude_fields__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_validators__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__include_fields__', '__init__', '__init_subclass__', '__iter__', '__json_encoder__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__post_root_validators__', '__pre_root_validators__', '__pretty__', '__private_attributes__', '__reduce__', '__reduce_ex__', '__repr__', '__repr_args__', '__repr_name__', '__repr_str__', '__rich_repr__', '__schema_cache__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__try_update_forward_refs__', '__validators__', '_abc_impl', '_calculate_keys', '_copy_and_set_values', '_decompose_class', '_enforce_dict_if_root', '_get_value', '_init_private_attribu
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer
import itertools
import random

def split_docs(documents, chunk_size=500, chunk_overlap=20):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    docs = text_splitter.split_documents(documents)
    return docs

# Assuming 'index' is already created and initialized

# Assuming 'docs' is a list of split documents
docs = split_docs(documents)

vector_dim = 384

# Example generator that generates many (id, vector) pairs for documents
docs_data_generator = map(lambda i_doc: (f'id-{i_doc[0]}', [random.random() for _ in range(vector_dim)]), enumerate(docs))

# Sentence Transformer model for embedding
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

def chunks(iterable, batch_size=100):
    """A helper function to break an iterable into chunks of size batch_size."""
    it = iter(iterable)
    chunk = tuple(itertools.islice(it, batch_size))
    while chunk:
        yield chunk
        chunk = tuple(itertools.islice(it, batch_size))

# Upsert data with 100 vectors per upsert request
batch_size = 100
for ids_vectors_chunk, doc_chunk in zip(chunks(docs_data_generator, batch_size=batch_size), chunks(docs, batch_size=batch_size)):
    # Embedding document chunks
    embeddings_chunk = model.encode([doc.page_content for doc in doc_chunk])

    metadata_list = [list((ids_vectors_chunk[i][0], doc_chunk[i].page_content)) for i in range(len(ids_vectors_chunk))]

    print(metadata_list[15])
    break
    # Assuming 'index' is the Pinecone index created and initialized earlier
    # index.upsert(vectors=ids_vectors_chunk, metadata=metadata_list)
# Out:
# ['id-15', 'Loca9on: Hawaii, USA Descrip9on: Situated on the prisPne beaches of Hawaii, the Kai Mana Resort is a tropical paradise exclusively for Diamond and Ascendant members. The resort boasts overwater bungalows with breathtaking ocean views, a private beach club, and a renowned wellness center. Members can indulge in unique experiences like sunset yacht cruises, Hawaiian cultural acPviPes, and exclusive access to secluded island locaPons.\n\nResorts exclusive for Gold and Pla9num membership levels:']

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.00035,
#  'namespaces': {'': {'vector_count': 35}},
#  'total_vector_count': 35}

# %%
# import random, itertools

# %%
# import numpy as np

# # Generating a random 384-dimensional vector
# random_vector = np.random.rand(384)

# # If you need to use the vector as a list
# random_vector_list = random_vector.tolist()

# # Printing the vector
# print(random_vector_list)
# Out:
# [0.6941410417355476, 0.23046372291260842, 0.3014219687098145, 0.28462960820398786, 0.8692683197497115, 0.26098209704668307, 0.41630301562218497, 0.8677822096167144, 0.6894396768869192, 0.4546240116846766, 0.35947578298595584, 0.8311937940986519, 0.3069518311144227, 0.6014454098033029, 0.20219872739641032, 0.7661490269905096, 0.45552248163290077, 0.31752969576134205, 0.898066257587486, 0.9060141319090671, 0.5739704066429874, 0.7394755325901319, 0.39235873830869494, 0.9355358452176951, 0.5211137323721943, 0.8913785657987628, 0.40655748302742123, 0.07793092825279135, 0.7713345448585299, 0.19104596963567555, 0.6069137227437691, 0.736046782842718, 0.5036602420206833, 0.5581134447565529, 0.06353978511076863, 0.6912969145972868, 0.8055954886469492, 0.6338627128069156, 0.7691752212572758, 0.43536873900456574, 0.4496699149949348, 0.9338723737306794, 0.15615978936518238, 0.7267382565508316, 0.33559698712687547, 0.4198410015387878, 0.3512323980517873, 0.10746347882641316, 0.9566361892494661, 0.
# ...

# %%
# def get_similiar_docs(query, k=1, score=False):
#     if score:
#         similar_docs = pc.similarity_search_with_score(index_name, query, k=k)
#     else:
#         similar_docs = pc.similarity_search(index_name, query, k=k)
#     return similar_docs

# query = "What is membership in timeshare hotel"
# similar_docs = get_similiar_docs(query)
# similar_docs
